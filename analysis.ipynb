# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
def loadContinuous(filename):
    return (np.loadtxt(filename, dtype = [("id","i4"),("time","f8"),("start","f8"), ( "end","f8"), ("diff","f8"),("ans","i4")],comments=None, delimiter=' ' , usecols=[1,3,5,7,9,11] )).view(np.recarray)
files=!ls results/?C*
name = [x.split(".")[0].split("/")[1] for x in files]
for (n,f) in zip(name, files): 
    print(n, f)
    vars()[n]=loadContinuous(f)
# Out:
# CCD1 results/CCD1.txt
# CCD2 results/CCD2.txt
# CCD3 results/CCD3.txt
# CCL1 results/CCL1.txt
# CCL2 results/CCL2.txt
# CCL3 results/CCL3.txt
# TCD1 results/TCD1.txt
# TCD2 results/TCD2.txt
# TCD3 results/TCD3.txt
# TCL1 results/TCL1.txt
# TCL2 results/TCL2.txt
# TCL3 results/TCL3.txt
# TCL-noglasses results/TCL-noglasses.txt
# WCD1 results/WCD1.txt
# WCD2 results/WCD2.txt
# WCD3 results/WCD3.txt
# WCL1 results/WCL1.txt
# WCL2 results/WCL2.txt
# WCL3 results/WCL3.txt
# WCL-noglasses results/WCL-noglasses.txt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def plot1(data):
    global ax
    dat=data[data.ans==1]
    plt.plot(dat.start ,dat.diff, dat.diff/dat.time,".", color="blue")
    dat=data[(data.ans==2 )| (data.ans == 0)]
    plt.plot(dat.start, dat.diff, dat.diff/dat.time,".", color="black")
    dat=data[data.ans==3]
    plt.plot(dat.start,dat.diff, dat.diff/dat.time,".", color="red")
    ax.set_xlabel("start")
    ax.set_ylabel("diff")
    ax.set_zlabel("speed")
    ax.set_xlim([0.25, 0.75])
    ax.set_ylim([-0.5, 0.5])
    ax.set_zlim([-0.1,0.1])

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
ax.set_title("CC??")
plot1(CCD1)
plot1(CCD2)
plot1(CCD3)
plot1(CCL1)
plot1(CCL2)
plot1(CCL3)
fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(CCD1)
plot1(CCD2)
plot1(CCD3)
ax.set_title("CCD?")
ax=fig.add_subplot(122, projection="3d")
plot1(CCL1)
plot1(CCL2)
plot1(CCL3)
ax.set_title("CCL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="908">
# Text(0.5,0.92,'CCL?')

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
plot1(WCD1)
plot1(WCD2)
plot1(WCD3)
plot1(WCL1)
plot1(WCL2)
plot1(WCL3)

ax.set_title("WC??")
fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(WCD1)
plot1(WCD2)
plot1(WCD3)
ax.set_title("WCD?")
ax=fig.add_subplot(122, projection="3d")
plot1(WCL1)
plot1(WCL2)
plot1(WCL3)
ax.set_title("WCL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="942">
# Text(0.5,0.92,'WCL?')

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
plot1(TCD1)
plot1(TCD2)
plot1(TCD3)

plot1(TCL1)
plot1(TCL2)
plot1(TCL3)

ax.set_title("TC??")
fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(TCD1)
plot1(TCD2)
plot1(TCD3)
ax.set_title("TCD?")
ax=fig.add_subplot(122, projection="3d")
plot1(TCL1)
plot1(TCL2)
plot1(TCL3)
ax.set_title("TCL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="930">
# Text(0.5,0.92,'TCL?')

# %%
def loadFlash(filename):
    return (np.loadtxt(filename, dtype = [("id","i4"),("time","f8"),("start","f8"), ( "end","f8"), ("diff","f8"),("ans","i4")],comments=None, delimiter=' ' , usecols=[1,3,5,7,9,11] )).view(np.recarray)
files=!ls results/?F*
name = [x.split(".")[0].split("/")[1] for x in files]
for (n,f) in zip(name, files): 
    print(n, f)
    vars()[n]=loadContinuous(f)
# Out:
# CFD1 results/CFD1.txt
# CFD2 results/CFD2.txt
# CFD3 results/CFD3.txt
# CFD4 results/CFD4.txt
# CFL1 results/CFL1.txt
# CFL2 results/CFL2.txt
# CFL3 results/CFL3.txt
# CFL4 results/CFL4.txt
# TFD1 results/TFD1.txt
# TFD2 results/TFD2.txt
# TFD3 results/TFD3.txt
# TFD4 results/TFD4.txt
# TFL1 results/TFL1.txt
# TFL2 results/TFL2.txt
# TFL3 results/TFL3.txt
# TFL4 results/TFL4.txt
# WFD1 results/WFD1.txt
# WFD2 results/WFD2.txt
# WFD3 results/WFD3.txt
# WFD4 results/WFD4.txt
# WFL1 results/WFL1.txt
# WFL2 results/WFL2.txt
# WFL3 results/WFL3.txt
# WFL4 results/WFL4.txt

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
plot1(CFD1)
plot1(CFD2)
plot1(CFD3)
plot1(CFD4)

plot1(CFL1)
plot1(CFL2)
plot1(CFL3)
plot1(CFL4)

ax.set_title("CF??")

fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(CFD1)
plot1(CFD2)
plot1(CFD3)
plot1(CFD4)
ax.set_title("CFD?")
ax=fig.add_subplot(122, projection="3d")
plot1(CFL1)
plot1(CFL2)
plot1(CFL3)
plot1(CFL4)
ax.set_title("CFL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="911">
# Text(0.5,0.92,'CFL?')

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
plot1(WFD1)
plot1(WFD2)
plot1(WFD3)
plot1(WFD4)

plot1(WFL1)
plot1(WFL2)
plot1(WFL3)
plot1(WFL4)

ax.set_title("WF??")

fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(WFD1)
plot1(WFD2)
plot1(WFD3)
plot1(WFD4)
ax.set_title("WFD?")
ax=fig.add_subplot(122, projection="3d")
plot1(WFL1)
plot1(WFL2)
plot1(WFL3)
plot1(WFL4)
ax.set_title("WFL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="944">
# Text(0.5,0.92,'WFL?')

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
plot1(TFD1)
plot1(TFD2)
plot1(TFD3)
plot1(TFD4)

plot1(TFL1)
plot1(TFL2)
plot1(TFL3)
plot1(TFL4)


ax.set_title("TF??")

fig=plt.figure()
ax=fig.add_subplot(121, projection="3d")
plot1(TFD1)
plot1(TFD2)
plot1(TFD3)
plot1(TFD4)
ax.set_title("TFD?")
ax=fig.add_subplot(122, projection="3d")
plot1(TFL1)
plot1(TFL2)
plot1(TFL3)
plot1(TFL4)
ax.set_title("TFL?")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="892">
# Text(0.5,0.92,'TFL?')
